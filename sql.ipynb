# %%
# %load_ext sql

# %%
# connect and test query

# %sql postgresql+psycopg2://dwh_owner:dwh_owner@127.0.0.1/dwh
    
# %sql SELECT * FROM dwh.fact_event LIMIT 5;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 5 rows affected.
# [(5, 1, datetime.date(2019, 2, 26), datetime.time(19, 0), 39, 1, datetime.date(2019, 2, 26), datetime.time(19, 0), 150, 150, 0),
#  (9, 2, datetime.date(2015, 11, 25), datetime.time(15, 45), 19, 9, datetime.date(2015, 11, 25), datetime.time(15, 45), None, 1, 0),
#  (11, 2, datetime.date(2015, 12, 26), datetime.time(8, 30), 19, 11, datetime.date(2015, 12, 26), datetime.time(8, 30), None, 1, 0),
#  (13, 6, datetime.date(2015, 9, 18), datetime.time(20, 0), 36, None, datetime.date(2015, 9, 18), datetime.time(20, 0), None, 75, 0),
#  (19, 2, datetime.date(2016, 1, 24), datetime.time(16, 0), 19, 12, datetime.date(2016, 1, 24), datetime.time(16, 0), None, 14, 0)]

# %% [markdown]
# ### Count event by date

# %%
# %%sql
#
# SELECT
#     date_trunc('month', event_date::timestamp) AS "event_date", count(*) AS "count"
# FROM
#     dwh.fact_event
# GROUP BY
#     date_trunc('month', CAST("dwh"."fact_event"."event_date" AS timestamp))
# ORDER BY
#     date_trunc('month', CAST("dwh"."fact_event"."event_date" AS timestamp)) ASC;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 150 rows affected.
# [(datetime.datetime(2007, 1, 1, 0, 0), 2),
#  (datetime.datetime(2007, 2, 1, 0, 0), 1),
#  (datetime.datetime(2007, 3, 1, 0, 0), 3),
#  (datetime.datetime(2007, 5, 1, 0, 0), 1),
#  (datetime.datetime(2007, 6, 1, 0, 0), 1),
#  (datetime.datetime(2007, 7, 1, 0, 0), 1),
#  (datetime.datetime(2007, 8, 1, 0, 0), 4),
#  (datetime.datetime(2007, 9, 1, 0, 0), 5),
#  (datetime.datetime(2007, 10, 1, 0, 0), 6),
#  (datetime.datetime(2007, 11, 1, 0, 0), 5),
#  (datetime.datetime(2007, 12, 1, 0, 0), 2),
#  (datetime.datetime(2008, 1, 1, 0, 0), 2),
#  (datetime.datetime(2008, 2, 1, 0, 0), 6),
#  (datetime.datetime(2008, 3, 1, 0, 0), 4),
#  (datetime.datetime(2008, 4, 1, 0, 0), 4),
#  (datetime.datetime(2008, 5, 1, 0, 0), 3),
#  (datetime.datetime(2008, 6, 1, 0, 0), 2),
#  (datetime.datetime(2008, 7, 1, 0, 0), 2),
#  (datetime.datetime(2008, 8, 1, 0, 0), 3),
#  (datetime.datetime(2008, 9, 1, 0, 0), 2),
#  (datetime.datetime(2008, 10, 1, 0, 0), 4),
#  (datetime.datetime(2008, 11, 1, 0, 0), 3),
#  (datetime.datetime(2008, 12, 1, 0, 0), 3),
#  (datetime.datetime(2009, 1, 1, 0, 0), 4),
#  (datetime.datetime(2009, 2, 1, 0, 0), 7),
#  (datetime.datetime(2009, 3, 1, 0, 0), 5),
#  (datetime.datetime(2009, 4, 1, 0, 0), 2),
#  (datetime.datetime(2009, 5, 1, 0, 0), 3),
#  (datetime.datetime(2009, 6, 1, 0, 0), 6),
#  (datetime.datetime(2009, 7, 1, 0, 0), 6),
#  (datetime.datetime(2009, 8, 1, 0, 0), 6),
#  (datetime.datetime(2009, 9, 1, 0, 0), 6),
#  (datetime.datetime(2009, 10, 1, 0, 0), 3),
#  (datetime.datetime(2009, 11, 1, 0, 0), 3),
#  (datetime.datetime(2009, 12, 1, 0, 0), 4),
#  (datetime.datetime(2010, 1, 1, 0, 0), 4),
#  (datetime.datetime(2010, 2, 1, 0, 0), 9),
#  (datetime.datetime(2010, 3, 1, 0, 0), 6),
#  (datetime.datetime(2010, 4, 1, 0, 0), 6),
#  (datetime.datetime(2010, 5, 1, 0, 0), 5),
#  (datetime.datetime(2010, 6, 1, 0, 0), 6),
#  (datetime.datetime(2010, 7, 1, 0, 0), 7),
#  (datetime.datetime(2010, 8, 1, 0, 0), 3),
#  (datetime.datetime(2010, 9, 1, 0, 0), 9),
#  (datetime.datetime(2010, 10, 1, 0, 0), 5),
#  (datetime.datetime(2010, 11, 1, 0, 0), 9),
#  (datetime.datetime(2010, 12, 1, 0, 0), 4),
#  (datetime.datetime(2011, 1, 1, 0, 0), 5),
#  (datetime.datetime(2011, 2, 1, 0, 0), 8),
#  (datetime.datetime(2011, 3, 1, 0, 0), 12),
#  (datetime.datetime(2011, 4, 1, 0, 0), 9),
#  (datetime.datetime(2011, 5, 1, 0, 0), 7),
#  (datetime.datetime(2011, 6, 1, 0, 0), 7),
#  (datetime.datetime(2011, 7, 1, 0, 0), 8),
#  (datetime.datetime(2011, 8, 1, 0, 0), 7),
#  (datetime.datetime(2011, 9, 1, 0, 0), 12),
#  (datetime.datetime(2011, 10, 1, 0, 0), 10),
#  (datetime.datetime(2011, 11, 1, 0, 0), 14),
#  (datetime.datetime(2011, 12, 1, 0, 0), 13),
#  (datetime.datetime(2012, 1, 1, 0, 0), 13),
#  (datetime.datetime(2012, 2, 1, 0, 0), 22),
#  (datetime.datetime(2012, 3, 1, 0, 0), 17),
#  (datetime.datetime(2012, 4, 1, 0, 0), 17),
#  (datetime.datetime(2012, 5, 1, 0, 0), 26),
#  (datetime.datetime(2012, 6, 1, 0, 0), 41),
#  (datetime.datetime(2012, 7, 1, 0, 0), 46),
#  (datetime.datetime(2012, 8, 1, 0, 0), 39),
#  (datetime.datetime(2012, 9, 1, 0, 0), 56),
#  (datetime.datetime(2012, 10, 1, 0, 0), 53),
#  (datetime.datetime(2012, 11, 1, 0, 0), 62),
#  (datetime.datetime(2012, 12, 1, 0, 0), 56),
#  (datetime.datetime(2013, 1, 1, 0, 0), 69),
#  (datetime.datetime(2013, 2, 1, 0, 0), 68),
#  (datetime.datetime(2013, 3, 1, 0, 0), 70),
#  (datetime.datetime(2013, 4, 1, 0, 0), 36),
#  (datetime.datetime(2013, 5, 1, 0, 0), 46),
#  (datetime.datetime(2013, 6, 1, 0, 0), 50),
#  (datetime.datetime(2013, 7, 1, 0, 0), 50),
#  (datetime.datetime(2013, 8, 1, 0, 0), 75),
#  (datetime.datetime(2013, 9, 1, 0, 0), 80),
#  (datetime.datetime(2013, 10, 1, 0, 0), 93),
#  (datetime.datetime(2013, 11, 1, 0, 0), 72),
#  (datetime.datetime(2013, 12, 1, 0, 0), 49),
#  (datetime.datetime(2014, 1, 1, 0, 0), 72),
#  (datetime.datetime(2014, 2, 1, 0, 0), 98),
#  (datetime.datetime(2014, 3, 1, 0, 0), 107),
#  (datetime.datetime(2014, 4, 1, 0, 0), 89),
#  (datetime.datetime(2014, 5, 1, 0, 0), 100),
#  (datetime.datetime(2014, 6, 1, 0, 0), 99),
#  (datetime.datetime(2014, 7, 1, 0, 0), 90),
#  (datetime.datetime(2014, 8, 1, 0, 0), 106),
#  (datetime.datetime(2014, 9, 1, 0, 0), 118),
#  (datetime.datetime(2014, 10, 1, 0, 0), 165),
#  (datetime.datetime(2014, 11, 1, 0, 0), 147),
#  (datetime.datetime(2014, 12, 1, 0, 0), 125),
#  (datetime.datetime(2015, 1, 1, 0, 0), 132),
#  (datetime.datetime(2015, 2, 1, 0, 0), 128),
#  (datetime.datetime(2015, 3, 1, 0, 0), 141),
#  (datetime.datetime(2015, 4, 1, 0, 0), 134),
#  (datetime.datetime(2015, 5, 1, 0, 0), 118),
#  (datetime.datetime(2015, 6, 1, 0, 0), 109),
#  (datetime.datetime(2015, 7, 1, 0, 0), 120),
#  (datetime.datetime(2015, 8, 1, 0, 0), 107),
#  (datetime.datetime(2015, 9, 1, 0, 0), 120),
#  (datetime.datetime(2015, 10, 1, 0, 0), 120),
#  (datetime.datetime(2015, 11, 1, 0, 0), 143),
#  (datetime.datetime(2015, 12, 1, 0, 0), 131),
#  (datetime.datetime(2016, 1, 1, 0, 0), 141),
#  (datetime.datetime(2016, 2, 1, 0, 0), 164),
#  (datetime.datetime(2016, 3, 1, 0, 0), 197),
#  (datetime.datetime(2016, 4, 1, 0, 0), 164),
#  (datetime.datetime(2016, 5, 1, 0, 0), 179),
#  (datetime.datetime(2016, 6, 1, 0, 0), 185),
#  (datetime.datetime(2016, 7, 1, 0, 0), 156),
#  (datetime.datetime(2016, 8, 1, 0, 0), 166),
#  (datetime.datetime(2016, 9, 1, 0, 0), 190),
#  (datetime.datetime(2016, 10, 1, 0, 0), 192),
#  (datetime.datetime(2016, 11, 1, 0, 0), 231),
#  (datetime.datetime(2016, 12, 1, 0, 0), 196),
#  (datetime.datetime(2017, 1, 1, 0, 0), 216),
#  (datetime.datetime(2017, 2, 1, 0, 0), 194),
#  (datetime.datetime(2017, 3, 1, 0, 0), 235),
#  (datetime.datetime(2017, 4, 1, 0, 0), 191),
#  (datetime.datetime(2017, 5, 1, 0, 0), 234),
#  (datetime.datetime(2017, 6, 1, 0, 0), 205),
#  (datetime.datetime(2017, 7, 1, 0, 0), 222),
#  (datetime.datetime(2017, 8, 1, 0, 0), 258),
#  (datetime.datetime(2017, 9, 1, 0, 0), 310),
#  (datetime.datetime(2017, 10, 1, 0, 0), 289),
#  (datetime.datetime(2017, 11, 1, 0, 0), 323),
#  (datetime.datetime(2017, 12, 1, 0, 0), 297),
#  (datetime.datetime(2018, 1, 1, 0, 0), 354),
#  (datetime.datetime(2018, 2, 1, 0, 0), 369),
#  (datetime.datetime(2018, 3, 1, 0, 0), 379),
#  (datetime.datetime(2018, 4, 1, 0, 0), 282),
#  (datetime.datetime(2018, 5, 1, 0, 0), 287),
#  (datetime.datetime(2018, 6, 1, 0, 0), 265),
#  (datetime.datetime(2018, 7, 1, 0, 0), 239),
#  (datetime.datetime(2018, 8, 1, 0, 0), 204),
#  (datetime.datetime(2018, 9, 1, 0, 0), 242),
#  (datetime.datetime(2018, 10, 1, 0, 0), 212),
#  (datetime.datetime(2018, 11, 1, 0, 0), 221),
#  (datetime.datetime(2018, 12, 1, 0, 0), 201),
#  (datetime.datetime(2019, 1, 1, 0, 0), 224),
#  (datetime.datetime(2019, 2, 1, 0, 0), 235),
#  (datetime.datetime(2019, 3, 1, 0, 0), 302),
#  (datetime.datetime(2019, 4, 1, 0, 0), 313),
#  (datetime.datetime(2019, 5, 1, 0, 0), 492),
#  (datetime.datetime(2019, 6, 1, 0, 0), 456),
#  (datetime.datetime(2019, 7, 1, 0, 0), 475)]

# %% [markdown]
# ### Group statistics

# %%
# %%sql
#
# SELECT
#     g.name,
#     SUM(f.yes_rsvp_count) AS total_rsvp,
#     COUNT(*) AS total_events,
#     AVG(f.yes_rsvp_count),
#     MAX(f.yes_rsvp_count),
#     MIN(f.yes_rsvp_count)
# FROM
#     dwh.fact_event f
#     INNER JOIN dwh.dim_group g ON f.group_key = g.group_key
# GROUP BY
#     g.name
# ORDER BY
#     total_rsvp DESC;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 189 rows affected.
# [('The Original Bangkok Language Exchange by TAO', 11361, 113, Decimal('100.5398230088495575'), 249, 1),
#  ('Bangkok Coffee and Movie Meetup', 4245, 200, Decimal('21.2250000000000000'), 83, 0),
#  ('ThaiPy - Bangkok Python Meetup', 4069, 59, Decimal('68.9661016949152542'), 223, 17),
#  ('Bangkok Cultural Exchange Meetup', 3918, 200, Decimal('19.5900000000000000'), 100, 1),
#  ('The Bangkok Wine Club', 3692, 200, Decimal('18.4600000000000000'), 89, 0),
#  ('Mundo Lingo Bangkok', 3594, 75, Decimal('47.9200000000000000'), 103, 6),
#  ('Japanese Class', 3361, 161, Decimal('20.8757763975155280'), 42, 3),
#  ('The Bangkok International Travel Group', 3271, 50, Decimal('65.4200000000000000'), 121, 4),
#  ('Bangkok Scientifique', 2713, 81, Decimal('33.4938271604938272'), 71, 4),
#  ('Wonder Women of Bangkok 🙅🏾🙅🏽🙅🏼🙅🏿🙅🏻', 2686, 96, Decimal('27.9791666666666667'), 69, 4),
#  ('Bangkok Volunteers', 2626, 200, Decimal('13.1300000000000000'), 90, 2),
#  ('BKK/hack – Code, Make, Learn, Share', 2558, 43, Decimal('59.4883720930232558'), 108, 22),
#  ('Tech@Agoda', 2498, 42, Decimal('59.4761904761904762'), 150, 1),
#  ('Bangkok Badminton', 2409, 200, Decimal('12.0450000000000000'), 29, 1),
#  ('Bangkok Culture Buddies - BCB', 2318, 204, Decimal('11.3627450980392157'), 33, 1),
#  ('Bangkok Young Expats Meetup', 2245, 52, Decimal('43.1730769230769231'), 110, 1),
#  ('Bangkok Photographers', 2231, 200, Decimal('11.1550000000000000'), 50, 1),
#  ('Zumba® in Bangkok!', 2208, 200, Decimal('11.0400000000000000'), 34, 0),
#  ('Life Drawing Sukhumvit Meetup', 2200, 200, Decimal('11.0000000000000000'), 26, 1),
#  ('Bangkok Vegan Meetup', 1979, 200, Decimal('9.8950000000000000'), 48, 1),
#  ('Bangkok Expat Women', 1964, 200, Decimal('9.8200000000000000'), 35, 1),
#  ('Girl Gone International (Bangkok)', 1915, 122, Decimal('15.6967213114754098'), 37, 3),
#  ('WordPress Bangkok', 1913, 52, Decimal('36.7884615384615385'), 204, 1),
#  ('BKK Volleyball Social Group (Bangkok)', 1910, 200, Decimal('9.5500000000000000'), 20, 1),
#  ('PD41 Bangkok Badminton Club', 1900, 104, Decimal('18.2692307692307692'), 35, 0),
#  ('❤❤Bangkok Thai Dinner & Meeting (Cooking+Eating+Culture)❤❤', 1837, 199, Decimal('9.2311557788944724'), 33, 0),
#  ('Little Bangkok Sangha : Meditation group', 1767, 200, Decimal('8.8350000000000000'), 35, 1),
#  ('Friends Fun Bangkok (FFB)', 1760, 125, Decimal('14.0800000000000000'), 33, 3),
#  ('Lumpini Running Club Bangkok', 1750, 200, Decimal('8.7500000000000000'), 25, 0),
#  ('Bangkok Satoshi Square (Bitcoin)', 1703, 200, Decimal('8.5150000000000000'), 39, 1),
#  ('Thailand Naturism Meetup', 1702, 180, Decimal('9.4555555555555556'), 61, 0),
#  ('TechGrind', 1605, 200, Decimal('8.0250000000000000'), 29, 1),
#  ('Bangkok Runners', 1600, 200, Decimal('8.0000000000000000'), 44, 0),
#  ('Agile Bangkok by agile66', 1576, 23, Decimal('68.5217391304347826'), 168, 3),
#  ('Bangkok Walking Adventures', 1547, 133, Decimal('11.6315789473684211'), 31, 0),
#  ('Badminton in Bangkok', 1528, 200, Decimal('7.6400000000000000'), 15, 0),
#  ('Bangkok Hiking and Outdoor', 1471, 125, Decimal('11.7680000000000000'), 30, 1),
#  ('Yoga with Evelin', 1421, 200, Decimal('7.1050000000000000'), 20, 1),
#  ('Thailand Progressive Jewish Community', 1386, 128, Decimal('10.8281250000000000'), 45, 0),
#  ('Bangkok Art Meetup', 1384, 128, Decimal('10.8125000000000000'), 27, 1),
#  ('Bangkok Ceramics and Pottery Club', 1378, 175, Decimal('7.8742857142857143'), 15, 3),
#  ('Bangkok eXcite Tribe', 1371, 200, Decimal('6.8550000000000000'), 34, 0),
#  ('Bangkok Personal Development', 1297, 131, Decimal('9.9007633587786260'), 38, 1),
#  ('Bangkok Scuba Diving Travel Club', 1294, 200, Decimal('6.4700000000000000'), 35, 0),
#  ('Bangkok Business Events', 1248, 102, Decimal('12.2352941176470588'), 55, 1),
#  ('Badzone Advanced Badminton games', 1118, 200, Decimal('5.5900000000000000'), 23, 1),
#  ('Bangkok Public Speaking Meetup', 1108, 200, Decimal('5.5400000000000000'), 20, 2),
#  ('BKK Fun (Events and Activities with Friends in Bangkok)', 1102, 200, Decimal('5.5100000000000000'), 20, 0),
#  ('Bangkok Gay Teatime', 1071, 200, Decimal('5.3550000000000000'), 15, 0),
#  ('Bangkok Javascript', 1056, 7, Decimal('150.8571428571428571'), 354, 80),
#  ("Let's Play Board Games at Ninive Board Game Store Bangkok", 967, 200, Decimal('4.8350000000000000'), 22, 0),
#  ('Fitness Bangkok', 962, 200, Decimal('4.8100000000000000'), 35, 0),
#  ('Bangkok Tennis Gang', 931, 200, Decimal('4.6550000000000000'), 13, 1),
#  ('Social coffee and bar Chess for fun in Bangkok', 927, 129, Decimal('7.1860465116279070'), 17, 0),
#  ('Bangkok Book Club', 821, 63, Decimal('13.0317460317460317'), 24, 1),
#  ('Polyglots in Bangkok', 801, 102, Decimal('7.8529411764705882'), 22, 1),
#  ('Bangkok THURSDAY : Free Energy Healing and Meditat', 791, 199, Decimal('3.9748743718592965'), 12, 0),
#  ('Startups & Beer', 791, 21, Decimal('37.6666666666666667'), 81, 7),
#  ('Canada Friendship Society', 788, 166, Decimal('4.7469879518072289'), 33, 0),
#  ('Brushing up your French', 744, 103, Decimal('7.2233009708737864'), 19, 0),
#  ('Key-Bangers Bangkok', 678, 90, Decimal('7.5333333333333333'), 15, 2),
#  ('Saturday Toastmasters Meetup in Bangkok', 614, 116, Decimal('5.2931034482758621'), 17, 0),
#  ('Anoop Shala: Kundalini Yoga in Bangkok', 595, 141, Decimal('4.2198581560283688'), 12, 1),
#  ('Bangkok Latin Dance Meetup', 590, 194, Decimal('3.0412371134020619'), 14, 0),
#  ('Bangkok.rb', 561, 18, Decimal('31.1666666666666667'), 55, 17),
#  ('Bangkok Expat Experts', 553, 153, Decimal('3.6143790849673203'), 13, 0),
#  ('Bangkok Shambhala Meditation Group', 550, 200, Decimal('2.7500000000000000'), 15, 1),
#  ('The Bangkok Libertarian Party Meetup Group', 539, 147, Decimal('3.6666666666666667'), 10, 0),
#  ('Bangkok Line Dance Meetup', 484, 86, Decimal('5.6279069767441860'), 10, 2),
#  ("Let's Talk Together", 476, 200, Decimal('2.3800000000000000'), 15, 1),
#  ('Crush Your Insecurity - Life Coaching in Bangkok', 439, 67, Decimal('6.5522388059701493'), 31, 1),
#  ('Bangkokian Nightlife', 437, 34, Decimal('12.8529411764705882'), 55, 1),
#  ('Bangkok German Language Meetup', 436, 77, Decimal('5.6623376623376623'), 11, 1),
#  ('"Timeless Classics" Book Club Bangkok', 432, 68, Decimal('6.3529411764705882'), 14, 2),
#  ('Bangkok Healthy Body and Mind', 430, 89, Decimal('4.8314606741573034'), 18, 0),
#  ('Bangkok Single Professionals Meetup', 429, 7, Decimal('61.2857142857142857'), 73, 41),
#  ('Capitol Toastmasters Community Club Meetup', 425, 156, Decimal('2.7243589743589744'), 8, 1),
#  ('ASEAN Critical Reading and Discussion Group/writing class', 423, 200, Decimal('2.1150000000000000'), 9, 0),
#  ('Bangkok Expat Social Drinks Club', 418, 8, Decimal('52.2500000000000000'), 100, 18),
#  ('Bangkok The Answer of "Why We Live" in Buddhism Meetup', 409, 200, Decimal('2.0450000000000000'), 9, 1),
#  ('BKK Sketchers Meetup', 394, 54, Decimal('7.2962962962962963'), 18, 1),
#  ('Learning Language day. Let’s say something.', 376, 33, Decimal('11.3939393939393939'), 29, 2),
#  ('Hula Hoop Dancing Class', 370, 102, Decimal('3.6274509803921569'), 12, 1),
#  ('Bangkok New in Town Meetup', 361, 6, Decimal('60.1666666666666667'), 72, 46),
#  ('GraphQL Bangkok', 355, 7, Decimal('50.7142857142857143'), 69, 27),
#  ('Latin Every Wednesdays', 354, 200, Decimal('1.7700000000000000'), 9, 1),
#  ('Startups in Bangkok', 334, 36, Decimal('9.2777777777777778'), 19, 1),
#  ('Bangkok Kizomba Meetup', 324, 81, Decimal('4.0000000000000000'), 13, 0),
#  ('Bangkok Golf Meetup', 322, 51, Decimal('6.3137254901960784'), 18, 1),
#  ('Bangkok Kirtan Meetup', 311, 60, Decimal('5.1833333333333333'), 12, 2),
#  ('Theatre Lovers in Bangkok', 308, 67, Decimal('4.5970149253731343'), 11, 1),
#  ('Zumba Meetup', 306, 189, Decimal('1.6190476190476190'), 8, 1),
#  ('Football Midweek @ Rama III Zone', 300, 200, Decimal('1.5000000000000000'), 5, 1),
#  ('Bangkok++ Weekend Adventure Trips', 286, 22, Decimal('13.0000000000000000'), 29, 1),
#  ('8-bit Bangkok', 283, 56, Decimal('5.0535714285714286'), 14, 1),
#  ('The HOME BKK', 282, 200, Decimal('1.4100000000000000'), 8, 1),
#  ('CodeSanook Meetup', 273, 4, Decimal('68.2500000000000000'), 75, 51),
#  ('Self Empowerment - Bangkok', 263, 18, Decimal('14.6111111111111111'), 60, 3),
#  ('Bkk Book Club', 260, 63, Decimal('4.1269841269841270'), 8, 1),
#  ('Bangkok Wellbeing Meetup', 250, 200, Decimal('1.2500000000000000'), 4, 0),
#  ('Bangkok Natural Health Meetup', 243, 31, Decimal('7.8387096774193548'), 18, 2),
#  ('Bangkok Food & Travel Buddies', 236, 9, Decimal('26.2222222222222222'), 150, 1),
#  ('Bangkok Philosophy and Great Classics Discussion Group', 231, 30, Decimal('7.7000000000000000'), 24, 2),
#  ('Bangkok Fine Art Photographers', 228, 62, Decimal('3.6774193548387097'), 11, 1),
#  ('Painting/Drawing Classes (Daytime)', 225, 201, Decimal('1.1194029850746269'), 4, 1),
#  ('Public Speaking Meetup @ Empower Toastmasters Club', 221, 55, Decimal('4.0181818181818182'), 12, 1),
#  ('Artisan things to do in Bangkok', 218, 200, Decimal('1.0900000000000000'), 3, 1),
#  ('Billy No-Mates! 🧸 Drinking, Chatting and Drinking more 🍻', 216, 7, Decimal('30.8571428571428571'), 60, 15),
#  ('The First Thai Toastmasters Club', 213, 77, Decimal('2.7662337662337662'), 14, 1),
#  ('Bangkok Roller Derby', 204, 159, Decimal('1.2830188679245283'), 7, 0),
#  ('Data Council Bangkok Data Engineering & Science', 186, 6, Decimal('31.0000000000000000'), 115, 1),
#  ('Bangkok Forex Introduction Meetup', 183, 86, Decimal('2.1279069767441860'), 8, 1),
#  ("Bangkok Women's Writers Group", 176, 29, Decimal('6.0689655172413793'), 12, 1),
#  ('Genevieve Caulfield Thailand Toastmasters Club', 175, 45, Decimal('3.8888888888888889'), 11, 1),
#  ('e-Commerce & Online Entrepreneurs @Thailand', 170, 32, Decimal('5.3125000000000000'), 25, 1),
#  ('BangkokScots - The Bangkok St Andrews Society', 163, 56, Decimal('2.9107142857142857'), 8, 1),
#  ('WOMEN WHO CODE BKK', 162, 25, Decimal('6.4800000000000000'), 26, 1),
#  ('Bangkok Games Meetup', 155, 80, Decimal('1.9375000000000000'), 6, 0),
#  ('BKK Volley', 148, 50, Decimal('2.9600000000000000'), 20, 0),
#  ('ICB Evening Worship', 147, 133, Decimal('1.1052631578947368'), 2, 1),
#  ('Meetups/Events by UnionSPACE', 146, 60, Decimal('2.4333333333333333'), 11, 1),
#  ('Bangkok Meet and Eat', 138, 11, Decimal('12.5454545454545455'), 23, 3),
#  ('Bangkok Events Club', 135, 42, Decimal('3.2142857142857143'), 12, 1),
#  ('Jam Cine Club', 131, 48, Decimal('2.7291666666666667'), 10, 1),
#  ('Bangkok Family Support and Kid Playground', 119, 117, Decimal('1.0170940170940171'), 2, 0),
#  ('Bangkok Sahaja Yoga Meditation', 117, 19, Decimal('6.1578947368421053'), 18, 4),
#  ('Pint of Science Thailand', 115, 9, Decimal('12.7777777777777778'), 28, 5),
#  ("Lilly's Yoga Pad", 113, 65, Decimal('1.7384615384615385'), 8, 1),
#  ('Elastic Thailand User Group', 110, 2, Decimal('55.0000000000000000'), 70, 40),
#  ('Bangkok X7: The Free Extreme Outdoor Bootcamp', 109, 37, Decimal('2.9459459459459459'), 7, 1),
#  ('Movie Night at Dice! Cafe (Ari)', 108, 15, Decimal('7.2000000000000000'), 16, 1),
#  ('InterniGo', 104, 23, Decimal('4.5217391304347826'), 11, 1),
#  ('Bangkok Singles Club', 101, 16, Decimal('6.3125000000000000'), 39, 2),
#  ('Self Empowerment Bangkok', 93, 33, Decimal('2.8181818181818182'), 11, 1),
#  ('Bangkok Anime Meetup', 92, 16, Decimal('5.7500000000000000'), 15, 0),
#  ('Bangkok Bitcoin Cash Meetup', 85, 5, Decimal('17.0000000000000000'), 21, 12),
#  ('ESL Teachers in Thailand', 84, 36, Decimal('2.3333333333333333'), 13, 1),
#  ('BK Dive Crew', 84, 10, Decimal('8.4000000000000000'), 17, 1),
#  ('Badminton At YWCA', 83, 8, Decimal('10.3750000000000000'), 14, 5),
#  ('Thailand Day Trips Meet Up', 83, 15, Decimal('5.5333333333333333'), 12, 1),
#  ('Become a Better Investor', 82, 27, Decimal('3.0370370370370370'), 10, 1),
#  ('Achieve Your Goals', 82, 24, Decimal('3.4166666666666667'), 10, 1),
#  ("Let's be vulnerable", 78, 21, Decimal('3.7142857142857143'), 8, 1),
#  ('Weekend Trips - Unseen Thailand', 77, 14, Decimal('5.5000000000000000'), 11, 2),
#  ('BIGx', 75, 24, Decimal('3.1250000000000000'), 18, 1),
#  ('Bangkok Online Marketing Club: for Entrepreneurs & Startups', 74, 3, Decimal('24.6666666666666667'), 49, 6),
#  ('Hatha Yoga with Olga', 73, 15, Decimal('4.8666666666666667'), 12, 1),
#  ('Healthy Lifestyle & Wellness', 68, 15, Decimal('4.5333333333333333'), 10, 2),
#  ('Bangkok Golden Years Seniors', 66, 5, Decimal('13.2000000000000000'), 17, 10),
#  ("You 'fer Euchre?", 66, 22, Decimal('3.0000000000000000'), 7, 1),
#  ('Project Management Institute (PMI) Thailand Chapter', 63, 27, Decimal('2.3333333333333333'), 7, 1),
#  ('Saksit Meditation & Healing Sessions', 62, 35, Decimal('1.7714285714285714'), 6, 1),
#  ('Scoop on 15 Wine Tasting', 61, 21, Decimal('2.9047619047619048'), 15, 1),
#  ('City English Project', 53, 12, Decimal('4.4166666666666667'), 9, 1),
#  ('Bangkok Foodies & Travelers Meetup', 48, 3, Decimal('16.0000000000000000'), 17, 14),
#  ('Become a Professional Coach', 43, 8, Decimal('5.3750000000000000'), 11, 2),
#  ('Reading Eckhart Tolle in Bangkok', 42, 5, Decimal('8.4000000000000000'), 10, 4),
#  ('Agile 30 - Bangkok', 37, 14, Decimal('2.6428571428571429'), 5, 1),
#  ('Bangkok Old Town Social Club', 37, 13, Decimal('2.8461538461538462'), 5, 1),
#  ('IBM AI Bangkok', 36, 2, Decimal('18.0000000000000000'), 30, 6),
#  ('Reiki - Inspiring Energy', 33, 9, Decimal('3.6666666666666667'), 10, 1),
#  ('Self-Improvement Book Club', 33, 5, Decimal('6.6000000000000000'), 12, 3),
#  ('Bangkok Meetup for Meditation', 32, 23, Decimal('1.3913043478260870'), 3, 1),
#  ('Insight Mindfulness Community Bangkok', 30, 3, Decimal('10.0000000000000000'), 12, 8),
#  ('Running And Walking in Bangkok', 28, 10, Decimal('2.8000000000000000'), 6, 1),
#  ('Bikram Style Hot Yoga in Bangkok', 27, 13, Decimal('2.0769230769230769'), 7, 1),
#  ('Bangkok Geeks', 26, 6, Decimal('4.3333333333333333'), 9, 1),
#  ('バンコク japanese交流', 26, 5, Decimal('5.2000000000000000'), 10, 1),
#  ('Spanish Bangkok', 24, 9, Decimal('2.6666666666666667'), 6, 1),
#  ('Bangkok Artists Meetup', 22, 2, Decimal('11.0000000000000000'), 13, 9),
#  ('BKK (Bangkok) Trips And Activities', 21, 3, Decimal('7.0000000000000000'), 16, 2),
#  ('Bangkok Innovators', 20, 1, Decimal('20.0000000000000000'), 20, 20),
#  ('Learning Thai with Mission', 17, 3, Decimal('5.6666666666666667'), 6, 5),
#  ('Bangkok Boxing Meetup Group', 15, 4, Decimal('3.7500000000000000'), 7, 1),
#  ('Bangkok Padel Gang', 15, 12, Decimal('1.2500000000000000'), 3, 0),
#  ("Bangkok's Heal Your Life (inspired by Louise L. Hay) Meetup", 13, 10, Decimal('1.3000000000000000'), 2, 1),
#  ('Teaching Tips with Richard James Rogers', 12, 2, Decimal('6.0000000000000000'), 7, 5),
#  ('CircleCI User Community in Bangkok', 12, 1, Decimal('12.0000000000000000'), 12, 12),
#  ("Paul's Reiki Meetup Group", 11, 7, Decimal('1.5714285714285714'), 3, 0),
#  ('Rock Stars', 10, 10, Decimal('1.00000000000000000000'), 1, 1),
#  ('Dance Club Party Group', 9, 5, Decimal('1.8000000000000000'), 4, 1),
#  ('esencia gay y no gay  latina y extranjeros', 9, 1, Decimal('9.0000000000000000'), 9, 9),
#  ('Bangkok Exclusive Meetup', 8, 2, Decimal('4.0000000000000000'), 5, 3),
#  ('Morning Coffee Time', 8, 1, Decimal('8.0000000000000000'), 8, 8),
#  ('Aussie expats in Bangkok meet and network', 7, 3, Decimal('2.3333333333333333'), 5, 1),
#  ('Bangkok VueJS and ColdBox MVC (CFML) Developers Group', 5, 3, Decimal('1.6666666666666667'), 3, 1),
#  ('Drucker Society Thai Meetup', 2, 2, Decimal('1.00000000000000000000'), 1, 1),
#  ('BKK Deep Dive: More productive co-working for digital nomads', 2, 2, Decimal('1.00000000000000000000'), 1, 1),
#  ('Travel Lovers Bangkok - Travelers, bloggers, digital nomads', 1, 1, Decimal('1.00000000000000000000'), 1, 1)]

# %% [markdown]
# ## Which group hosts the most events ?

# %%
# %%sql
#
# SELECT
#     g.name,
#     COUNT(*) AS total_events
# FROM
#     dwh.fact_event f
#     INNER JOIN dwh.dim_group g ON f.group_key = g.group_key
# GROUP BY
#     g.name
# ORDER BY
#     total_events DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 10 rows affected.
# [('Bangkok Culture Buddies - BCB', 204),
#  ('Painting/Drawing Classes (Daytime)', 201),
#  ('Artisan things to do in Bangkok', 200),
#  ("Let's Play Board Games at Ninive Board Game Store Bangkok", 200),
#  ('Bangkok Photographers', 200),
#  ('Zumba® in Bangkok!', 200),
#  ("Let's Talk Together", 200),
#  ('Bangkok Badminton', 200),
#  ('Bangkok Public Speaking Meetup', 200),
#  ('The Bangkok Wine Club', 200)]

# %% [markdown]
# ### The highest attendance of all time (Event)

# %%
# %%sql
#
# SELECT
#     e.name,
#     g.name,
#     yes_rsvp_count
# FROM
#     dwh.fact_event f
#     INNER JOIN dwh.dim_group g ON f.group_key = g.group_key
#     INNER JOIN dwh.dim_event e ON f.event_key = e.event_key
# ORDER BY
#     yes_rsvp_count DESC
# LIMIT 10;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 10 rows affected.
# [('BKK.js#8', 'Bangkok Javascript', 354),
#  ('First Event of The year @ aloft Hotel Sukhumwit 11[swimming pool (Level 10)]', 'The Original Bangkok Language Exchange by TAO', 249),
#  ('July ThaiPy: python automation for legal work + overview of python GUI modules', 'ThaiPy - Bangkok Python Meetup', 223),
#  ('BLACK Night #2 @ "Roof 409" 8PM-11.45PM', 'The Original Bangkok Language Exchange by TAO', 208),
#  ('How to design and create themes faster and better.', 'WordPress Bangkok', 204),
#  ('BKK.JS : Frontend War (Angular x React x Vue)', 'Bangkok Javascript', 190),
#  ('ThaiPy: MicroPython + Django DB indexes + how to talk at pycon', 'ThaiPy - Bangkok Python Meetup', 181),
#  ('July Colorful Meetup @ ZAKS! Sukhumwit 11', 'The Original Bangkok Language Exchange by TAO', 174),
#  ('Hubba presents Why Agile Teams Have Nothing to Do With Business Agility', 'Agile Bangkok by agile66', 168),
#  ('Activity Time ! with Language Exchange Meetup!! 9Floor !!check it out new room!', 'The Original Bangkok Language Exchange by TAO', 167)]

# %% [markdown]
# ### Popular time of the day

# %%
# %%sql
#
# SELECT
#     time_of_day,
#     COUNT(*) AS total_events
# FROM
#     dwh.fact_event f
#     LEFT JOIN dwh.dim_time t ON f.time_key = t.time_pk
# GROUP BY
#     time_of_day
# ORDER BY
#     total_events DESC
# LIMIT 20;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 20 rows affected.
# [('19:00', 2678),
#  ('18:30', 1751),
#  ('18:00', 1307),
#  ('20:00', 1072),
#  ('10:00', 883),
#  ('16:00', 632),
#  ('13:00', 491),
#  ('11:00', 467),
#  ('17:00', 442),
#  ('09:00', 411),
#  ('15:00', 402),
#  ('19:30', 384),
#  ('17:30', 331),
#  ('14:00', 316),
#  ('12:00', 316),
#  ('10:30', 295),
#  ('08:00', 265),
#  ('18:15', 204),
#  ('07:00', 194),
#  ('19:15', 179)]

# %% [markdown]
# ### Rollup RSVP

# %%
# %%sql
#
# SELECT
#     c.name AS category_name,
#     g.name AS group_name,
#     SUM(f.yes_rsvp_count) AS total_rsvp
# FROM
#     dwh.fact_event f
#     LEFT JOIN dwh.dim_category c ON f.category_key = c.category_key
#     LEFT JOIN dwh.dim_group g ON f.group_key = g.group_key
# GROUP BY
#     ROLLUP(c.name, g.name)
# ORDER BY
#     category_name;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 218 rows affected.
# [('Arts & Culture', 'BKK Sketchers Meetup', 394),
#  ('Arts & Culture', 'Bangkok Art Meetup', 1384),
#  ('Arts & Culture', 'Bangkok Artists Meetup', 22),
#  ('Arts & Culture', 'Bangkok Ceramics and Pottery Club', 1378),
#  ('Arts & Culture', 'Life Drawing Sukhumvit Meetup', 2200),
#  ('Arts & Culture', 'Painting/Drawing Classes (Daytime)', 225),
#  ('Arts & Culture', 'Theatre Lovers in Bangkok', 308),
#  ('Arts & Culture', None, 5911),
#  ('Book Clubs', '"Timeless Classics" Book Club Bangkok', 432),
#  ('Book Clubs', 'Bangkok Book Club', 821),
#  ('Book Clubs', None, 1253),
#  ('Career & Business', 'Achieve Your Goals', 82),
#  ('Career & Business', 'BKK Deep Dive: More productive co-working for digital nomads', 2),
#  ('Career & Business', 'Bangkok Business Events', 1248),
#  ('Career & Business', 'Bangkok Exclusive Meetup', 8),
#  ('Career & Business', 'Bangkok Expat Experts', 553),
#  ('Career & Business', 'Bangkok Forex Introduction Meetup', 183),
#  ('Career & Business', 'Bangkok Innovators', 20),
#  ('Career & Business', 'Bangkok Online Marketing Club: for Entrepreneurs & Startups', 74),
#  ('Career & Business', 'Bangkok Public Speaking Meetup', 1108),
#  ('Career & Business', 'Bangkok Satoshi Square (Bitcoin)', 1703),
#  ('Career & Business', 'Bangkok eXcite Tribe', 1371),
#  ('Career & Business', 'Become a Better Investor', 82),
#  ('Career & Business', 'Capitol Toastmasters Community Club Meetup', 425),
#  ('Career & Business', 'Drucker Society Thai Meetup', 2),
#  ('Career & Business', 'Genevieve Caulfield Thailand Toastmasters Club', 175),
#  ('Career & Business', 'Saturday Toastmasters Meetup in Bangkok', 614),
#  ('Career & Business', 'Startups in Bangkok', 334),
#  ('Career & Business', 'The First Thai Toastmasters Club', 213),
#  ('Career & Business', 'e-Commerce & Online Entrepreneurs @Thailand', 170),
#  ('Career & Business', None, 8367),
#  ('Community & Environment', 'Bangkok Volunteers', 2626),
#  ('Community & Environment', 'Meetups/Events by UnionSPACE', 146),
#  ('Community & Environment', None, 2772),
#  ('Dancing', 'Bangkok Kizomba Meetup', 324),
#  ('Dancing', 'Bangkok Latin Dance Meetup', 590),
#  ('Dancing', 'Bangkok Line Dance Meetup', 484),
#  ('Dancing', 'Hula Hoop Dancing Class', 370),
#  ('Dancing', 'Latin Every Wednesdays', 354),
#  ('Dancing', None, 2122),
#  ('Education & Learning', 'BIGx', 75),
#  ('Education & Learning', 'Bangkok Philosophy and Great Classics Discussion Group', 231),
#  ('Education & Learning', 'Bangkok Scientifique', 2713),
#  ('Education & Learning', 'Bangkok Walking Adventures', 1547),
#  ('Education & Learning', 'Pint of Science Thailand', 115),
#  ('Education & Learning', 'Public Speaking Meetup @ Empower Toastmasters Club', 221),
#  ('Education & Learning', 'Self-Improvement Book Club', 33),
#  ('Education & Learning', 'Teaching Tips with Richard James Rogers', 12),
#  ('Education & Learning', None, 4947),
#  ('Fashion & Beauty', 'The HOME BKK', 282),
#  ('Fashion & Beauty', None, 282),
#  ('Fitness', 'Bangkok Boxing Meetup Group', 15),
#  ('Fitness', 'Bangkok Healthy Body and Mind', 430),
#  ('Fitness', 'Bangkok Runners', 1600),
#  ('Fitness', 'Bangkok X7: The Free Extreme Outdoor Bootcamp', 109),
#  ('Fitness', 'Fitness Bangkok', 962),
#  ('Fitness', 'Hatha Yoga with Olga', 73),
#  ('Fitness', 'Lumpini Running Club Bangkok', 1750),
#  ('Fitness', 'Running And Walking in Bangkok', 28),
#  ('Fitness', 'Zumba Meetup', 306),
#  ('Fitness', 'Zumba® in Bangkok!', 2208),
#  ('Fitness', None, 7481),
#  ('Food & Drink', 'Bangkok Coffee and Movie Meetup', 4245),
#  ('Food & Drink', 'Bangkok Food & Travel Buddies', 236),
#  ('Food & Drink', 'Bangkok Foodies & Travelers Meetup', 48),
#  ('Food & Drink', 'Bangkok Meet and Eat', 138),
#  ('Food & Drink', 'Bangkok Vegan Meetup', 1979),
#  ('Food & Drink', 'Friends Fun Bangkok (FFB)', 1760),
#  ('Food & Drink', 'Scoop on 15 Wine Tasting', 61),
#  ('Food & Drink', 'The Bangkok Wine Club', 3692),
#  ('Food & Drink', '❤❤Bangkok Thai Dinner & Meeting (Cooking+Eating+Culture)❤❤', 1837),
#  ('Food & Drink', None, 13996),
#  ('Games', '8-bit Bangkok', 283),
#  ('Games', 'Bangkok Games Meetup', 155),
#  ('Games', "Let's Play Board Games at Ninive Board Game Store Bangkok", 967),
#  ('Games', 'Social coffee and bar Chess for fun in Bangkok', 927),
#  ('Games', "You 'fer Euchre?", 66),
#  ('Games', None, 2398),
#  ('Health & Wellbeing', 'Anoop Shala: Kundalini Yoga in Bangkok', 595),
#  ('Health & Wellbeing', 'Bangkok Kirtan Meetup', 311),
#  ('Health & Wellbeing', 'Bangkok Meetup for Meditation', 32),
#  ('Health & Wellbeing', 'Bangkok Natural Health Meetup', 243),
#  ('Health & Wellbeing', 'Bangkok Personal Development', 1297),
#  ('Health & Wellbeing', 'Bangkok Shambhala Meditation Group', 550),
#  ('Health & Wellbeing', 'Bangkok THURSDAY : Free Energy Healing and Meditat', 791),
#  ('Health & Wellbeing', 'Bangkok Wellbeing Meetup', 250),
#  ('Health & Wellbeing', 'Become a Professional Coach', 43),
#  ('Health & Wellbeing', 'Bikram Style Hot Yoga in Bangkok', 27),
#  ('Health & Wellbeing', 'Crush Your Insecurity - Life Coaching in Bangkok', 439),
#  ('Health & Wellbeing', 'Healthy Lifestyle & Wellness', 68),
#  ('Health & Wellbeing', 'Insight Mindfulness Community Bangkok', 30),
#  ('Health & Wellbeing', "Lilly's Yoga Pad", 113),
#  ('Health & Wellbeing', 'Self Empowerment - Bangkok', 263),
#  ('Health & Wellbeing', 'Yoga with Evelin', 1421),
#  ('Health & Wellbeing', None, 6473),
#  ('Hobbies & Crafts', 'Artisan things to do in Bangkok', 218),
#  ('Hobbies & Crafts', None, 218),
#  ('LGBT', 'Bangkok Gay Teatime', 1071),
#  ('LGBT', 'esencia gay y no gay  latina y extranjeros', 9),
#  ('LGBT', None, 1080),
#  ('Language & Ethnic Identity', 'ASEAN Critical Reading and Discussion Group/writing class', 423),
#  ('Language & Ethnic Identity', 'Aussie expats in Bangkok meet and network', 7),
#  ('Language & Ethnic Identity', 'Bangkok Cultural Exchange Meetup', 3918),
#  ('Language & Ethnic Identity', 'Bangkok Culture Buddies - BCB', 2318),
#  ('Language & Ethnic Identity', 'Bangkok German Language Meetup', 436),
#  ('Language & Ethnic Identity', 'BangkokScots - The Bangkok St Andrews Society', 163),
#  ('Language & Ethnic Identity', 'Bkk Book Club', 260),
#  ('Language & Ethnic Identity', 'Brushing up your French', 744),
#  ('Language & Ethnic Identity', 'Canada Friendship Society', 788),
#  ('Language & Ethnic Identity', 'City English Project', 53),
#  ('Language & Ethnic Identity', 'ESL Teachers in Thailand', 84),
#  ('Language & Ethnic Identity', 'Japanese Class', 3361),
#  ('Language & Ethnic Identity', 'Learning Language day. Let’s say something.', 376),
#  ('Language & Ethnic Identity', 'Learning Thai with Mission', 17),
#  ('Language & Ethnic Identity', "Let's Talk Together", 476),
#  ('Language & Ethnic Identity', 'PD41 Bangkok Badminton Club', 1900),
#  ('Language & Ethnic Identity', 'Polyglots in Bangkok', 801),
#  ('Language & Ethnic Identity', 'Spanish Bangkok', 24),
#  ('Language & Ethnic Identity', 'The Original Bangkok Language Exchange by TAO', 11361),
#  ('Language & Ethnic Identity', None, 27510),
#  ('Lifestyle', 'Thailand Naturism Meetup', 1702),
#  ('Lifestyle', None, 1702),
#  ('Movements & Politics', 'The Bangkok Libertarian Party Meetup Group', 539),
#  ('Movements & Politics', None, 539),
#  ('Movies & Film', 'Jam Cine Club', 131),
#  ('Movies & Film', 'Movie Night at Dice! Cafe (Ari)', 108),
#  ('Movies & Film', 'Mundo Lingo Bangkok', 3594),
#  ('Movies & Film', None, 3833),
#  ('New Age & Spirituality', 'Bangkok Sahaja Yoga Meditation', 117),
#  ('New Age & Spirituality', 'Bangkok The Answer of "Why We Live" in Buddhism Meetup', 409),
#  ('New Age & Spirituality', "Bangkok's Heal Your Life (inspired by Louise L. Hay) Meetup", 13),
#  ('New Age & Spirituality', "Let's be vulnerable", 78),
#  ('New Age & Spirituality', 'Little Bangkok Sangha : Meditation group', 1767),
#  ('New Age & Spirituality', "Paul's Reiki Meetup Group", 11),
#  ('New Age & Spirituality', 'Reading Eckhart Tolle in Bangkok', 42),
#  ('New Age & Spirituality', 'Reiki - Inspiring Energy', 33),
#  ('New Age & Spirituality', 'Rock Stars', 10),
#  ('New Age & Spirituality', 'Saksit Meditation & Healing Sessions', 62),
#  ('New Age & Spirituality', 'Self Empowerment Bangkok', 93),
#  ('New Age & Spirituality', None, 2635),
#  ('Outdoors & Adventure', 'BK Dive Crew', 84),
#  ('Outdoors & Adventure', 'BKK (Bangkok) Trips And Activities', 21),
#  ('Outdoors & Adventure', 'Bangkok Hiking and Outdoor', 1471),
#  ('Outdoors & Adventure', 'Bangkok Scuba Diving Travel Club', 1294),
#  ('Outdoors & Adventure', 'Bangkok++ Weekend Adventure Trips', 286),
#  ('Outdoors & Adventure', 'Thailand Day Trips Meet Up', 83),
#  ('Outdoors & Adventure', 'The Bangkok International Travel Group', 3271),
#  ('Outdoors & Adventure', 'Travel Lovers Bangkok - Travelers, bloggers, digital nomads', 1),
#  ('Outdoors & Adventure', 'Weekend Trips - Unseen Thailand', 77),
#  ('Outdoors & Adventure', None, 6588),
#  ('Parents & Family', 'Bangkok Family Support and Kid Playground', 119),
#  ('Parents & Family', None, 119),
#  ('Photography', 'Bangkok Fine Art Photographers', 228),
#  ('Photography', 'Bangkok Photographers', 2231),
#  ('Photography', None, 2459),
#  ('Religion & Beliefs', 'ICB Evening Worship', 147),
#  ('Religion & Beliefs', 'Thailand Progressive Jewish Community', 1386),
#  ('Religion & Beliefs', None, 1533),
#  ('Sci-Fi & Fantasy', 'Bangkok Anime Meetup', 92),
#  ('Sci-Fi & Fantasy', 'Bangkok Geeks', 26),
#  ('Sci-Fi & Fantasy', None, 118),
#  ('Singles', 'Bangkok Single Professionals Meetup', 429),
#  ('Singles', None, 429),
#  ('Socializing', 'BKK Fun (Events and Activities with Friends in Bangkok)', 1102),
#  ('Socializing', 'Bangkok Events Club', 135),
#  ('Socializing', 'Bangkok Expat Social Drinks Club', 418),
#  ('Socializing', 'Bangkok Expat Women', 1964),
#  ('Socializing', 'Bangkok Golden Years Seniors', 66),
#  ('Socializing', 'Bangkok New in Town Meetup', 361),
#  ('Socializing', 'Bangkok Old Town Social Club', 37),
#  ('Socializing', 'Bangkok Singles Club', 101),
#  ('Socializing', 'Bangkok Young Expats Meetup', 2245),
#  ('Socializing', 'Bangkokian Nightlife', 437),
#  ('Socializing', 'Billy No-Mates! 🧸 Drinking, Chatting and Drinking more 🍻', 216),
#  ('Socializing', 'Dance Club Party Group', 9),
#  ('Socializing', 'Girl Gone International (Bangkok)', 1915),
#  ('Socializing', 'InterniGo', 104),
#  ('Socializing', 'Morning Coffee Time', 8),
#  ('Socializing', 'Wonder Women of Bangkok 🙅🏾🙅🏽🙅🏼🙅🏿🙅🏻', 2686),
#  ('Socializing', 'バンコク japanese交流', 26),
#  ('Socializing', None, 11830),
#  ('Sports & Recreation', 'BKK Volley', 148),
#  ('Sports & Recreation', 'BKK Volleyball Social Group (Bangkok)', 1910),
#  ('Sports & Recreation', 'Badminton At YWCA', 83),
#  ('Sports & Recreation', 'Badminton in Bangkok', 1528),
#  ('Sports & Recreation', 'Badzone Advanced Badminton games', 1118),
#  ('Sports & Recreation', 'Bangkok Badminton', 2409),
#  ('Sports & Recreation', 'Bangkok Golf Meetup', 322),
#  ('Sports & Recreation', 'Bangkok Padel Gang', 15),
#  ('Sports & Recreation', 'Bangkok Roller Derby', 204),
#  ('Sports & Recreation', 'Bangkok Tennis Gang', 931),
#  ('Sports & Recreation', 'Football Midweek @ Rama III Zone', 300),
#  ('Sports & Recreation', None, 8968),
#  ('Tech', 'Agile 30 - Bangkok', 37),
#  ('Tech', 'Agile Bangkok by agile66', 1576),
#  ('Tech', 'BKK/hack – Code, Make, Learn, Share', 2558),
#  ('Tech', 'Bangkok Bitcoin Cash Meetup', 85),
#  ('Tech', 'Bangkok Javascript', 1056),
#  ('Tech', 'Bangkok VueJS and ColdBox MVC (CFML) Developers Group', 5),
#  ('Tech', 'Bangkok.rb', 561),
#  ('Tech', 'CircleCI User Community in Bangkok', 12),
#  ('Tech', 'CodeSanook Meetup', 273),
#  ('Tech', 'Data Council Bangkok Data Engineering & Science', 186),
#  ('Tech', 'Elastic Thailand User Group', 110),
#  ('Tech', 'GraphQL Bangkok', 355),
#  ('Tech', 'IBM AI Bangkok', 36),
#  ('Tech', 'Project Management Institute (PMI) Thailand Chapter', 63),
#  ('Tech', 'Startups & Beer', 791),
#  ('Tech', 'Tech@Agoda', 2498),
#  ('Tech', 'TechGrind', 1605),
#  ('Tech', 'ThaiPy - Bangkok Python Meetup', 4069),
#  ('Tech', 'WOMEN WHO CODE BKK', 162),
#  ('Tech', 'WordPress Bangkok', 1913),
#  ('Tech', None, 17951),
#  ('Writing', "Bangkok Women's Writers Group", 176),
#  ('Writing', 'Key-Bangers Bangkok', 678),
#  ('Writing', None, 854),
#  (None, None, 144368)]

# %% [markdown]
# ### Crosstab by week day

# %%
# %%sql
#
# WITH pivot_date AS (
#     SELECT
#         *
#     FROM
#         CROSSTAB(
#             $$SELECT
#                 year,
#                 week_day_name,
#                 SUM(yes_rsvp_count)::INT AS total_yes_rsvp
#             FROM
#                 dwh.fact_event f
#                 LEFT JOIN dwh.dim_date d ON f.date_key = d.date_pk
#             GROUP BY
#                 year, week_day_name
#             ORDER BY
#                 year,
#                 CASE
#                     WHEN week_day_name = 'Sunday' THEN 1
#                     WHEN week_day_name = 'Monday' THEN 2
#                     WHEN week_day_name = 'Tuesday' THEN 3
#                     WHEN week_day_name = 'Wednesday' THEN 4
#                     WHEN week_day_name = 'Thursday' THEN 5
#                     WHEN week_day_name = 'Friday' THEN 6
#                     WHEN week_day_name = 'Saturday' THEN 7
#                 END$$
#         ) AS ct(year int, sunday int, monday int, tuesday int, wednesday int, thursday int, friday int, saturday int)
# ),
# total_yes_rsvp_count AS (
#     SELECT
#         year,
#         SUM(yes_rsvp_count) AS total_yes_rsvp
#     FROM
#         dwh.fact_event f
#     LEFT JOIN dwh.dim_date d ON f.date_key = d.date_pk
#     GROUP BY
#         year
#     ORDER BY
#         year
# )
#
# SELECT
#     p.*,
#     t.total_yes_rsvp
# FROM
#     pivot_date p
# INNER JOIN
#     total_yes_rsvp_count t ON p.year = t.year;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 13 rows affected.
# [(2007, 3, 37, 1, 11, 47, 11, 41, 151),
#  (2008, 1, 15, 20, 11, 27, 51, 57, 182),
#  (2009, 17, 46, 116, 8, 85, 112, 93, 477),
#  (2010, 21, 116, 46, 39, 93, 259, 183, 757),
#  (2011, 174, 53, 142, 101, 152, 188, 361, 1171),
#  (2012, 1071, 282, 357, 636, 553, 640, 1991, 5530),
#  (2013, 1535, 112, 726, 1063, 1092, 942, 6353, 11823),
#  (2014, 2925, 722, 1028, 1531, 1803, 560, 7160, 15729),
#  (2015, 2402, 1142, 1975, 2401, 2235, 1314, 5047, 16516),
#  (2016, 2833, 1655, 2555, 3286, 4423, 1381, 5679, 21812),
#  (2017, 4112, 1498, 2728, 3606, 4678, 1684, 6068, 24374),
#  (2018, 2557, 633, 5005, 2788, 4847, 1413, 7349, 24592),
#  (2019, 1929, 1098, 3522, 2997, 3055, 2987, 5666, 21254)]

# %% [markdown]
# ### Some window functions

# %%
# %%sql
#
# WITH cte AS (SELECT
#     g.name AS group_name,
#     f.yes_rsvp_count,
#     CASE
#         WHEN yes_rsvp_count > LAG(f.yes_rsvp_count, 1) OVER (
#         PARTITION BY g.name
#         ORDER BY f.event_date
#     ) THEN 1 ELSE 0
#     END AS better
# FROM
#     dwh.fact_event f
#     LEFT JOIN dwh.dim_group g ON f.group_key = g.group_key
#     LEFT JOIN dwh.dim_event e ON f.event_key = e.event_key
# )
#
# SELECT
#     group_name,
#     COUNT(*) AS total_events,
#     SUM(better) AS total_better,
#     SUM(better)::Float / COUNT(*)::Float AS better_percentage
# FROM
#     cte
# GROUP BY
#     group_name
# ORDER BY
#     SUM(better)::Float / COUNT(*)::Float DESC;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 189 rows affected.
# [('Become a Professional Coach', 8, 5, 0.625),
#  ('BK Dive Crew', 10, 6, 0.6),
#  ('バンコク japanese交流', 5, 3, 0.6),
#  ('Self-Improvement Book Club', 5, 3, 0.6),
#  ('Bangkok Golden Years Seniors', 5, 3, 0.6),
#  ('WordPress Bangkok', 52, 31, 0.596153846153846),
#  ('Bangkok Single Professionals Meetup', 7, 4, 0.571428571428571),
#  ('Billy No-Mates! 🧸 Drinking, Chatting and Drinking more 🍻', 7, 4, 0.571428571428571),
#  ('Bangkok Food & Travel Buddies', 9, 5, 0.555555555555556),
#  ('Learning Language day. Let’s say something.', 33, 18, 0.545454545454545),
#  ('Bangkok Old Town Social Club', 13, 7, 0.538461538461538),
#  ('Bangkok Business Events', 102, 54, 0.529411764705882),
#  ('Bangkok Cultural Exchange Meetup', 200, 104, 0.52),
#  ('Bangkok Scientifique', 81, 42, 0.518518518518518),
#  ('Genevieve Caulfield Thailand Toastmasters Club', 45, 23, 0.511111111111111),
#  ('IBM AI Bangkok', 2, 1, 0.5),
#  ('8-bit Bangkok', 56, 28, 0.5),
#  ('Wonder Women of Bangkok 🙅🏾🙅🏽🙅🏼🙅🏿🙅🏻', 96, 48, 0.5),
#  ('Bangkok New in Town Meetup', 6, 3, 0.5),
#  ('Running And Walking in Bangkok', 10, 5, 0.5),
#  ('Bangkok Artists Meetup', 2, 1, 0.5),
#  ('BKK Fun (Events and Activities with Friends in Bangkok)', 200, 98, 0.49),
#  ('Bangkok Vegan Meetup', 200, 98, 0.49),
#  ('Bangkok Badminton', 200, 98, 0.49),
#  ('BKK/hack – Code, Make, Learn, Share', 43, 21, 0.488372093023256),
#  ('Bangkok Coffee and Movie Meetup', 200, 97, 0.485),
#  ('Thailand Naturism Meetup', 180, 87, 0.483333333333333),
#  ('Bangkok Young Expats Meetup', 52, 25, 0.480769230769231),
#  ('The Bangkok International Travel Group', 50, 24, 0.48),
#  ('Friends Fun Bangkok (FFB)', 125, 60, 0.48),
#  ('Japanese Class', 161, 77, 0.478260869565217),
#  ('Agile Bangkok by agile66', 23, 11, 0.478260869565217),
#  ('Girl Gone International (Bangkok)', 122, 58, 0.475409836065574),
#  ('Bangkok Volunteers', 200, 95, 0.475),
#  ('Bangkok Sahaja Yoga Meditation', 19, 9, 0.473684210526316),
#  ('Bangkokian Nightlife', 34, 16, 0.470588235294118),
#  ('Bangkok Golf Meetup', 51, 24, 0.470588235294118),
#  ('Polyglots in Bangkok', 102, 48, 0.470588235294118),
#  ('Life Drawing Sukhumvit Meetup', 200, 94, 0.47),
#  ('Thailand Progressive Jewish Community', 128, 60, 0.46875),
#  ('Bangkok Philosophy and Great Classics Discussion Group', 30, 14, 0.466666666666667),
#  ("Let's Play Board Games at Ninive Board Game Store Bangkok", 200, 93, 0.465),
#  ('Bangkok Runners', 200, 93, 0.465),
#  ('Bangkok Satoshi Square (Bitcoin)', 200, 93, 0.465),
#  ('Bangkok Ceramics and Pottery Club', 175, 81, 0.462857142857143),
#  ('Theatre Lovers in Bangkok', 67, 31, 0.462686567164179),
#  ('Bangkok Art Meetup', 128, 59, 0.4609375),
#  ('Bkk Book Club', 63, 29, 0.46031746031746),
#  ('The Original Bangkok Language Exchange by TAO', 113, 52, 0.460176991150442),
#  ('Bangkok++ Weekend Adventure Trips', 22, 10, 0.454545454545455),
#  ('The Bangkok Wine Club', 200, 90, 0.45),
#  ('Bangkok Expat Women', 200, 90, 0.45),
#  ('Social coffee and bar Chess for fun in Bangkok', 129, 58, 0.449612403100775),
#  ("Bangkok Women's Writers Group", 29, 13, 0.448275862068966),
#  ('BKK Volleyball Social Group (Bangkok)', 200, 89, 0.445),
#  ('Bangkok Scuba Diving Travel Club', 200, 89, 0.445),
#  ('Bangkok Book Club', 63, 28, 0.444444444444444),
#  ('Startups in Bangkok', 36, 16, 0.444444444444444),
#  ('❤❤Bangkok Thai Dinner & Meeting (Cooking+Eating+Culture)❤❤', 199, 88, 0.442211055276382),
#  ('Bangkok Line Dance Meetup', 86, 38, 0.441860465116279),
#  ('ThaiPy - Bangkok Python Meetup', 59, 26, 0.440677966101695),
#  ('TechGrind', 200, 88, 0.44),
#  ('WOMEN WHO CODE BKK', 25, 11, 0.44),
#  ('Bangkok Anime Meetup', 16, 7, 0.4375),
#  ('Bangkok Personal Development', 131, 57, 0.435114503816794),
#  ('Little Bangkok Sangha : Meditation group', 200, 87, 0.435),
#  ('Zumba® in Bangkok!', 200, 87, 0.435),
#  ('InterniGo', 23, 10, 0.434782608695652),
#  ('Crush Your Insecurity - Life Coaching in Bangkok', 67, 29, 0.432835820895522),
#  ('Startups & Beer', 21, 9, 0.428571428571429),
#  ('GraphQL Bangkok', 7, 3, 0.428571428571429),
#  ('Agile 30 - Bangkok', 14, 6, 0.428571428571429),
#  ('Tech@Agoda', 42, 18, 0.428571428571429),
#  ('Bangkok Javascript', 7, 3, 0.428571428571429),
#  ('Canada Friendship Society', 166, 71, 0.427710843373494),
#  ('Brushing up your French', 103, 44, 0.427184466019417),
#  ('BKK Sketchers Meetup', 54, 23, 0.425925925925926),
#  ('Bangkok Gay Teatime', 200, 85, 0.425),
#  ('Yoga with Evelin', 200, 85, 0.425),
#  ('Lumpini Running Club Bangkok', 200, 85, 0.425),
#  ('Bangkok eXcite Tribe', 200, 85, 0.425),
#  ('Key-Bangers Bangkok', 90, 38, 0.422222222222222),
#  ('Bangkok Natural Health Meetup', 31, 13, 0.419354838709677),
#  ('ESL Teachers in Thailand', 36, 15, 0.416666666666667),
#  ('Bangkok Healthy Body and Mind', 89, 37, 0.415730337078652),
#  ('Bangkok Tennis Gang', 200, 83, 0.415),
#  ('Bangkok Photographers', 200, 83, 0.415),
#  ('Badminton in Bangkok', 200, 83, 0.415),
#  ('Bangkok Walking Adventures', 133, 55, 0.413533834586466),
#  ('Mundo Lingo Bangkok', 75, 31, 0.413333333333333),
#  ('Bangkok THURSDAY : Free Energy Healing and Meditat', 199, 82, 0.412060301507538),
#  ('"Timeless Classics" Book Club Bangkok', 68, 28, 0.411764705882353),
#  ('Anoop Shala: Kundalini Yoga in Bangkok', 141, 58, 0.411347517730496),
#  ("You 'fer Euchre?", 22, 9, 0.409090909090909),
#  ('Bangkok Hiking and Outdoor', 125, 51, 0.408),
#  ('Project Management Institute (PMI) Thailand Chapter', 27, 11, 0.407407407407407),
#  ('Become a Better Investor', 27, 11, 0.407407407407407),
#  ('Bangkok Culture Buddies - BCB', 204, 83, 0.406862745098039),
#  ('Saturday Toastmasters Meetup in Bangkok', 116, 47, 0.405172413793103),
#  ('Thailand Day Trips Meet Up', 15, 6, 0.4),
#  ('Public Speaking Meetup @ Empower Toastmasters Club', 55, 22, 0.4),
#  ('Hatha Yoga with Olga', 15, 6, 0.4),
#  ('Movie Night at Dice! Cafe (Ari)', 15, 6, 0.4),
#  ('Bangkok Bitcoin Cash Meetup', 5, 2, 0.4),
#  ('Bangkok Latin Dance Meetup', 194, 77, 0.396907216494845),
#  ('Jam Cine Club', 48, 19, 0.395833333333333),
#  ('Bangkok Kizomba Meetup', 81, 32, 0.395061728395062),
#  ('Bangkok Expat Experts', 153, 60, 0.392156862745098),
#  ('The First Thai Toastmasters Club', 77, 30, 0.38961038961039),
#  ('Bangkok German Language Meetup', 77, 30, 0.38961038961039),
#  ('Self Empowerment - Bangkok', 18, 7, 0.388888888888889),
#  ('Meetups/Events by UnionSPACE', 60, 23, 0.383333333333333),
#  ('Hula Hoop Dancing Class', 102, 39, 0.382352941176471),
#  ("Let's be vulnerable", 21, 8, 0.380952380952381),
#  ('PD41 Bangkok Badminton Club', 104, 39, 0.375),
#  ('Badminton At YWCA', 8, 3, 0.375),
#  ('Bangkok Expat Social Drinks Club', 8, 3, 0.375),
#  ('Bangkok Singles Club', 16, 6, 0.375),
#  ('Capitol Toastmasters Community Club Meetup', 156, 58, 0.371794871794872),
#  ('Bangkok Public Speaking Meetup', 200, 74, 0.37),
#  ('Bangkok Kirtan Meetup', 60, 22, 0.366666666666667),
#  ('Badzone Advanced Badminton games', 200, 73, 0.365),
#  ('Bangkok Forex Introduction Meetup', 86, 31, 0.36046511627907),
#  ('Bangkok Shambhala Meditation Group', 200, 72, 0.36),
#  ('Bangkok Events Club', 42, 15, 0.357142857142857),
#  ('Weekend Trips - Unseen Thailand', 14, 5, 0.357142857142857),
#  ('Bangkok Foodies & Travelers Meetup', 3, 1, 0.333333333333333),
#  ('Bangkok Geeks', 6, 2, 0.333333333333333),
#  ('Spanish Bangkok', 9, 3, 0.333333333333333),
#  ('Reiki - Inspiring Energy', 9, 3, 0.333333333333333),
#  ('Learning Thai with Mission', 3, 1, 0.333333333333333),
#  ('City English Project', 12, 4, 0.333333333333333),
#  ('The Bangkok Libertarian Party Meetup Group', 147, 49, 0.333333333333333),
#  ('BKK (Bangkok) Trips And Activities', 3, 1, 0.333333333333333),
#  ('Bangkok Online Marketing Club: for Entrepreneurs & Startups', 3, 1, 0.333333333333333),
#  ('Bangkok VueJS and ColdBox MVC (CFML) Developers Group', 3, 1, 0.333333333333333),
#  ('Healthy Lifestyle & Wellness', 15, 5, 0.333333333333333),
#  ('Scoop on 15 Wine Tasting', 21, 7, 0.333333333333333),
#  ('Insight Mindfulness Community Bangkok', 3, 1, 0.333333333333333),
#  ('Achieve Your Goals', 24, 8, 0.333333333333333),
#  ('Bangkok.rb', 18, 6, 0.333333333333333),
#  ('Fitness Bangkok', 200, 65, 0.325),
#  ('Bangkok Games Meetup', 80, 26, 0.325),
#  ('Bangkok X7: The Free Extreme Outdoor Bootcamp', 37, 12, 0.324324324324324),
#  ('Bangkok Fine Art Photographers', 62, 20, 0.32258064516129),
#  ('BangkokScots - The Bangkok St Andrews Society', 56, 18, 0.321428571428571),
#  ('Saksit Meditation & Healing Sessions', 35, 10, 0.285714285714286),
#  ("Paul's Reiki Meetup Group", 7, 2, 0.285714285714286),
#  ('Latin Every Wednesdays', 200, 57, 0.285),
#  ('e-Commerce & Online Entrepreneurs @Thailand', 32, 9, 0.28125),
#  ('Bangkok Meet and Eat', 11, 3, 0.272727272727273),
#  ('Bangkok Meetup for Meditation', 23, 6, 0.260869565217391),
#  ('ASEAN Critical Reading and Discussion Group/writing class', 200, 51, 0.255),
#  ('CodeSanook Meetup', 4, 1, 0.25),
#  ('Bangkok Padel Gang', 12, 3, 0.25),
#  ('BIGx', 24, 6, 0.25),
#  ("Lilly's Yoga Pad", 65, 16, 0.246153846153846),
#  ('BKK Volley', 50, 12, 0.24),
#  ('Bangkok The Answer of "Why We Live" in Buddhism Meetup', 200, 48, 0.24),
#  ('Football Midweek @ Rama III Zone', 200, 47, 0.235),
#  ('Bikram Style Hot Yoga in Bangkok', 13, 3, 0.230769230769231),
#  ("Let's Talk Together", 200, 43, 0.215),
#  ('The HOME BKK', 200, 41, 0.205),
#  ('Reading Eckhart Tolle in Bangkok', 5, 1, 0.2),
#  ('Dance Club Party Group', 5, 1, 0.2),
#  ("Bangkok's Heal Your Life (inspired by Louise L. Hay) Meetup", 10, 2, 0.2),
#  ('Bangkok Roller Derby', 159, 30, 0.188679245283019),
#  ('Bangkok Wellbeing Meetup', 200, 36, 0.18),
#  ('Data Council Bangkok Data Engineering & Science', 6, 1, 0.166666666666667),
#  ('Self Empowerment Bangkok', 33, 5, 0.151515151515152),
#  ('Zumba Meetup', 189, 28, 0.148148148148148),
#  ('Pint of Science Thailand', 9, 1, 0.111111111111111),
#  ('ICB Evening Worship', 133, 13, 0.0977443609022556),
#  ('Painting/Drawing Classes (Daytime)', 201, 18, 0.0895522388059701),
#  ('Artisan things to do in Bangkok', 200, 15, 0.075),
#  ('Bangkok Family Support and Kid Playground', 117, 4, 0.0341880341880342),
#  ('Bangkok Boxing Meetup Group', 4, 0, 0.0),
#  ('Bangkok Exclusive Meetup', 2, 0, 0.0),
#  ('Bangkok Innovators', 1, 0, 0.0),
#  ('Morning Coffee Time', 1, 0, 0.0),
#  ('Drucker Society Thai Meetup', 2, 0, 0.0),
#  ('CircleCI User Community in Bangkok', 1, 0, 0.0),
#  ('esencia gay y no gay  latina y extranjeros', 1, 0, 0.0),
#  ('Travel Lovers Bangkok - Travelers, bloggers, digital nomads', 1, 0, 0.0),
#  ('Elastic Thailand User Group', 2, 0, 0.0),
#  ('Aussie expats in Bangkok meet and network', 3, 0, 0.0),
#  ('Rock Stars', 10, 0, 0.0),
#  ('Teaching Tips with Richard James Rogers', 2, 0, 0.0),
#  ('BKK Deep Dive: More productive co-working for digital nomads', 2, 0, 0.0)]

# %%
# %%sql
#
# SELECT
#     g.name AS group_name,
#     e.name AS event_name,
#     f.yes_rsvp_count,
#     f.event_date
# FROM
#     dwh.fact_event f
#     LEFT JOIN dwh.dim_group g ON f.group_key = g.group_key
#     LEFT JOIN dwh.dim_event e ON f.event_key = e.event_key
# WHERE
#     g.name = 'Self-Improvement Book Club'
# ORDER BY
#     f.event_date;
# Out:
#  * postgresql+psycopg2://dwh_owner:***@127.0.0.1/dwh
# 5 rows affected.
# [('Self-Improvement Book Club', "Let's improve together by reading! - 1st Meeting of the Club", 3, datetime.date(2017, 8, 27)),
#  ('Self-Improvement Book Club', 'The 7 Habits of Highly Effective People: Roundtable discussion', 9, datetime.date(2017, 10, 29)),
#  ('Self-Improvement Book Club', 'The Power of Habit by Charles Duhigg', 12, datetime.date(2018, 2, 10)),
#  ('Self-Improvement Book Club', 'Take Life to the Next Level!  Reading - The Big Leap by Gay Hendricks ', 4, datetime.date(2019, 1, 8)),
#  ('Self-Improvement Book Club', '1 WEEK BOOK CHALLENGE:  Cultivating An Unshakable Character by Jim Rohn', 5, datetime.date(2019, 6, 24))]
